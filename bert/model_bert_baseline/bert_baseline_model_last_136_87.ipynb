# %% [markdown]
# # Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
# sys.path.remove('/content/drive/MyDrive/Colab Notebooks/W266 Final Project/master/helper_functions')
sys.path.append('/content/drive/MyDrive/Colab Notebooks/W266 Final Project/master/helper_functions')

# %%
for p in sys.path:
  print(p)
# Out:
# /content
# /env/python
# /usr/lib/python37.zip
# /usr/lib/python3.7
# /usr/lib/python3.7/lib-dynload
# /usr/local/lib/python3.7/dist-packages
# /usr/lib/python3/dist-packages
# /usr/local/lib/python3.7/dist-packages/IPython/extensions
# /root/.ipython
# /content/drive/MyDrive/Colab Notebooks/W266 Final Project/master/helper_functions
# /content/drive/MyDrive/Colab Notebooks/W266 Final Project/master/helper_functions

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
import math
import random
import pickle
import time

from numpy.linalg import norm
from scipy.stats import rankdata
# from transformers import BertTokenizer, TFBertModel

# from tensorflow.keras import layers
# from tensorflow.keras.layers import Dense, Flatten

import parse
import bert_funcs as bf
import evaluation
import similarity_score_dicts

# %% [markdown]
# # Import Bert Embedding Batches

# %%
# Load embeddings dictionary from file
embeddings_from_file1 = open('/content/drive/MyDrive/Colab Notebooks/W266 Final Project/data/embeddings/bert_batches_last_136_87/bert_batch_1.pickle', 'rb')
embeddings_1 = pickle.load(embeddings_from_file1)
len(embeddings_1)
# Out:
# 20000

# %%
# Load embeddings dictionary from file
embeddings_from_file2 = open('/content/drive/MyDrive/Colab Notebooks/W266 Final Project/data/embeddings/bert_batches_last_136_87/bert_batch_2.pickle', 'rb')
embeddings_2 = pickle.load(embeddings_from_file2)
len(embeddings_2)
# Out:
# 20000

# %%
# Load embeddings dictionary from file
embeddings_from_file3 = open('/content/drive/MyDrive/Colab Notebooks/W266 Final Project/data/embeddings/bert_batches_last_136_87/bert_batch_3.pickle', 'rb')
embeddings_3 = pickle.load(embeddings_from_file3)
len(embeddings_3)
# Out:
# 20000

# %%
# Load embeddings dictionary from file
embeddings_from_file4 = open('/content/drive/MyDrive/Colab Notebooks/W266 Final Project/data/embeddings/bert_batches_last_136_87/bert_batch_4.pickle', 'rb')
embeddings_4 = pickle.load(embeddings_from_file4)
len(embeddings_4)
# Out:
# 20000

# %%
# Load embeddings dictionary from file
embeddings_from_file5 = open('/content/drive/MyDrive/Colab Notebooks/W266 Final Project/data/embeddings/bert_batches_last_136_87/bert_batch_5.pickle', 'rb')
embeddings_5 = pickle.load(embeddings_from_file5)
len(embeddings_5)
# Out:
# 10959

# %%
len(embeddings_1)+len(embeddings_2)+len(embeddings_3)+len(embeddings_4)+len(embeddings_5)
# Out:
# 90959

# %% [markdown]
# # Combine batch dictionaries

# %%
bert_embeddings = {}

# %%
bert_embeddings.update(embeddings_1)
len(bert_embeddings)
# Out:
# 20000

# %%
bert_embeddings.update(embeddings_2)
len(bert_embeddings)
# Out:
# 40000

# %%
bert_embeddings.update(embeddings_3)
len(bert_embeddings)
# Out:
# 60000

# %%
bert_embeddings.update(embeddings_4)
len(bert_embeddings)
# Out:
# 80000

# %%
bert_embeddings.update(embeddings_5)
len(bert_embeddings)
# Out:
# 90959

# %%
# Save embeddings dictionary to file
embeddings_dict_to_file = open('/content/drive/MyDrive/Colab Notebooks/W266 Final Project/data/embeddings/bert_embeddings_last_136_87.pickle', 'wb')
pickle.dump(bert_embeddings, embeddings_dict_to_file)

# %%
# Load embeddings dictionary from file
embeds_from_file = open('/content/drive/MyDrive/Colab Notebooks/W266 Final Project/data/embeddings/bert_embeddings_last_136_87.pickle', 'rb')
bert_embeddings_last_136_87 = pickle.load(embeds_from_file)
len(bert_embeddings_last_136_87)
# Out:
# 90959

# %%
bert_embeddings_last_136_87[list(bert_embeddings_last_136_87.keys())[0]]
# Out:
# <tf.Tensor: shape=(768,), dtype=float32, numpy=
# array([ 3.74160528e-01,  2.80811757e-01, -1.48026615e-01,  1.87920809e-01,
#        -2.51528114e-01, -3.96225564e-02, -1.23727061e-02,  1.68342382e-01,
#         8.13930295e-03, -1.27572849e-01,  2.50966787e-01,  5.15421033e-01,
#         8.72132629e-02,  1.07157387e-01, -3.89538288e-01, -5.10013290e-02,
#        -1.38546020e-01, -3.51827368e-02, -3.06849688e-01,  1.35262251e-01,
#        -2.11539581e-01, -8.85082707e-02,  6.67413883e-03,  1.56023607e-01,
#         3.17838043e-01, -1.81713343e-01,  2.48121172e-01,  4.09717381e-01,
#         2.10519567e-01,  1.95152387e-01,  9.94327366e-02,  1.91310480e-01,
#         2.14118540e-01, -7.04771206e-02,  2.84871366e-03,  1.15044899e-01,
#        -2.95186132e-01,  1.40146181e-01, -5.73121086e-02,  3.79053950e-01,
#         1.42305553e-01,  9.96822864e-02,  4.71634082e-02,  5.24478592e-02,
#         5.77793680e-02, -1.80581346e-01,  8.01427960e-02,  3.12543586e-02,
# ...

# %%
np.inner(bert_embeddings_last_136_87[list(bert_embeddings_last_136_87.keys())[0]], bert_embeddings_last_136_87[list(bert_embeddings_last_136_87.keys())[0]]) / (norm(bert_embeddings_last_136_87[list(bert_embeddings_last_136_87.keys())[0]]) * norm(bert_embeddings_last_136_87[list(bert_embeddings_last_136_87.keys())[0]]))
# Out:
# 0.99999994

# %% [markdown]
# # Import Global Q-A Test Dictionary

# %%
test_from_file = open('/content/drive/MyDrive/Colab Notebooks/W266 Final Project/data/q_a_dict_test.pickle', 'rb')
test_qa_dict = pickle.load(test_from_file)
len(test_qa_dict)
# Out:
# 3063

# %% [markdown]
# # Create Cosine Similarity Dictionary

# %%
cosine_similarity_dict = similarity_score_dicts.create_similarity_score_dict(test_qa_dict, bert_embeddings_last_136_87, 'cosine')
len(cosine_similarity_dict)
# Out:
# 3063

# %% [markdown]
# # Create Rankings Dictionary

# %%
rankings_dict = similarity_score_dicts.compute_rankings(cosine_similarity_dict)
len(rankings_dict)
# Out:
# 3063

# %% [markdown]
# # Evaluate Results

# %%
evaluation.calculate_mrr(test_qa_dict, rankings_dict)
# Out:
# MRR: 0.5633555130616813
# 0.5633555130616813

# %%
evaluation.calculate_accuracy(test_qa_dict, rankings_dict)
# Out:
# Number correct: 1212
# Number incorrect 1851
# Total: 3063
# Accuracy: 39.569049951028404
# 39.569049951028404

# %%
evaluation.calculate_metrics(test_qa_dict, rankings_dict)
# Out:
# TP: 1212
# FP: 1846
# TN: 25718
# FN: 1854
# Precision: 0.39633747547416615
# Recall: 0.3953033268101761
# Accuracy: 0.8792033953640223
# (0.39633747547416615, 0.3953033268101761, 0.8792033953640223)

# %%
1212+1846+25718+1854
# Out:
# 30630

# %%
rankings_dict
# Out:
# {55661929: [(55662134, 4),
#   (55662053, 3),
#   (55661981, 1),
#   (64717925, 2),
#   (52250747, 9),
#   (47805233, 7),
#   (60398311, 5),
#   (47860893, 8),
#   (50565510, 6),
#   (54576739, 10)],
#  55664544: [(55664726, 6),
#   (55664585, 8),
#   (55664663, 7),
#   (51611111, 2),
#   (55118801, 1),
#   (61665527, 9),
#   (58582708, 3),
#   (59407189, 5),
#   (61027439, 10),
#   (42335581, 4)],
#  55644043: [(55665839, 6),
#   (55644071, 4),
#   (55644063, 3),
#   (43736281, 9),
#   (56789874, 2),
#   (61598381, 8),
#   (38446230, 7),
#   (57796365, 5),
#   (60590369, 10),
#   (37491434, 1)],
#  55668648: [(55669044, 4),
#   (55668752, 3),
#   (40313673, 10),
#   (61019118, 5),
#   (42076860, 7),
#   (46987965, 1),
#   (42858938, 2),
#   (55284252, 8),
#   (62841773, 6),
#   (42798604, 9)],
#  55707618: [(55708016, 4),
#   (62266543, 5),
#   (41499488, 2),
#   (51143548, 9),
#   (35772065, 8),
#   (50058945, 7),
#   (38295966, 3),
#   (46439272, 6),
#   (56278456, 1),
# ...
