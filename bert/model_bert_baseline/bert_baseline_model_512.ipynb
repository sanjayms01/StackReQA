# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Imports

# %%
import sys
# sys.path.remove('/content/drive/MyDrive/Colab Notebooks/W266 Final Project/master/helper_functions')
sys.path.append('/content/drive/MyDrive/Colab Notebooks/W266 Final Project/master/helper_functions')

# %%
for p in sys.path:
  print(p)
# Out:
# /content
# /env/python
# /usr/lib/python37.zip
# /usr/lib/python3.7
# /usr/lib/python3.7/lib-dynload
# /usr/local/lib/python3.7/dist-packages
# /usr/lib/python3/dist-packages
# /usr/local/lib/python3.7/dist-packages/IPython/extensions
# /root/.ipython
# /content/drive/MyDrive/Colab Notebooks/W266 Final Project/master/helper_functions

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
import math
import random
import pickle
import time

from numpy.linalg import norm
from scipy.stats import rankdata
# from transformers import BertTokenizer, TFBertModel

# from tensorflow.keras import layers
# from tensorflow.keras.layers import Dense, Flatten

import parse
import bert_funcs as bf
import evaluation
import similarity_score_dicts

# %% [markdown]
# # Import Bert Embedding Batches

# %%
# Load embeddings dictionary from file
embeddings_from_file1 = open('/content/drive/MyDrive/Colab Notebooks/W266 Final Project/data/embeddings/bert_batches_512/bert_batch_1.pickle', 'rb')
embeddings_1 = pickle.load(embeddings_from_file1)
len(embeddings_1)
# Out:
# 20000

# %%
# Load embeddings dictionary from file
embeddings_from_file2 = open('/content/drive/MyDrive/Colab Notebooks/W266 Final Project/data/embeddings/bert_batches_512/bert_batch_2.pickle', 'rb')
embeddings_2 = pickle.load(embeddings_from_file2)
len(embeddings_2)
# Out:
# 20000

# %%
# Load embeddings dictionary from file
embeddings_from_file3 = open('/content/drive/MyDrive/Colab Notebooks/W266 Final Project/data/embeddings/bert_batches_512/bert_batch_3.pickle', 'rb')
embeddings_3 = pickle.load(embeddings_from_file3)
len(embeddings_3)
# Out:
# 20000

# %%
# Load embeddings dictionary from file
embeddings_from_file4 = open('/content/drive/MyDrive/Colab Notebooks/W266 Final Project/data/embeddings/bert_batches_512/bert_batch_4.pickle', 'rb')
embeddings_4 = pickle.load(embeddings_from_file4)
len(embeddings_4)
# Out:
# 20000

# %%
# Load embeddings dictionary from file
embeddings_from_file5 = open('/content/drive/MyDrive/Colab Notebooks/W266 Final Project/data/embeddings/bert_batches_512/bert_batch_5.pickle', 'rb')
embeddings_5 = pickle.load(embeddings_from_file5)
len(embeddings_5)
# Out:
# 10959

# %%
# # Load embeddings dictionary from file
# embeddings_from_file6 = open('/content/drive/MyDrive/Colab Notebooks/W266 Final Project/data/embeddings/bert_batch_6.pickle', 'rb')
# embeddings_6 = pickle.load(embeddings_from_file6)
# len(embeddings_6)

# %%
# # Load embeddings dictionary from file
# embeddings_from_file7 = open('/content/drive/MyDrive/Colab Notebooks/W266 Final Project/data/embeddings/bert_batch_7.pickle', 'rb')
# embeddings_7 = pickle.load(embeddings_from_file7)
# len(embeddings_7)

# %%
# # Load embeddings dictionary from file
# embeddings_from_file8 = open('/content/drive/MyDrive/Colab Notebooks/W266 Final Project/data/embeddings/bert_batch_8.pickle', 'rb')
# embeddings_8 = pickle.load(embeddings_from_file8)
# len(embeddings_8)

# %%
# # Load embeddings dictionary from file
# embeddings_from_file9 = open('/content/drive/MyDrive/Colab Notebooks/W266 Final Project/data/embeddings/bert_batch_9.pickle', 'rb')
# embeddings_9 = pickle.load(embeddings_from_file9)
# len(embeddings_9)

# %%
13460 + 17159 + 14383 + 14056 + 10959 + 6540 + 2841 + 5617 + 5944
# Out:
# 90959

# %% [markdown]
# # Combine batch dictionaries

# %%
bert_embeddings = {}

# %%
bert_embeddings.update(embeddings_1)
len(bert_embeddings)
# Out:
# 20000

# %%
bert_embeddings.update(embeddings_2)
len(bert_embeddings)
# Out:
# 40000

# %%
bert_embeddings.update(embeddings_3)
len(bert_embeddings)
# Out:
# 60000

# %%
bert_embeddings.update(embeddings_4)
len(bert_embeddings)
# Out:
# 80000

# %%
bert_embeddings.update(embeddings_5)
len(bert_embeddings)
# Out:
# 90959

# %%
# bert_embeddings.update(embeddings_6)
# len(bert_embeddings)

# %%
# bert_embeddings.update(embeddings_7)
# len(bert_embeddings)

# %%
# bert_embeddings.update(embeddings_8)
# len(bert_embeddings)

# %%
# bert_embeddings.update(embeddings_9)
# len(bert_embeddings)

# %%
# Save embeddings dictionary to file
embeddings_dict_to_file = open('/content/drive/MyDrive/Colab Notebooks/W266 Final Project/data/embeddings/bert_embeddings_512.pickle', 'wb')
pickle.dump(bert_embeddings, embeddings_dict_to_file)

# %%
# Load embeddings dictionary from file
embeds_from_file = open('/content/drive/MyDrive/Colab Notebooks/W266 Final Project/data/embeddings/bert_embeddings_512.pickle', 'rb')
bert_embeddings_512 = pickle.load(embeds_from_file)
len(bert_embeddings_512)
# Out:
# 90959

# %%
bert_embeddings_512[list(bert_embeddings_512.keys())[0]]
# Out:
# <tf.Tensor: shape=(768,), dtype=float32, numpy=
# array([ 5.26779175e-01,  8.97260532e-02, -3.57277901e-03,  1.79706607e-04,
#        -2.99898177e-01,  5.86450100e-03, -5.04927635e-02,  1.56183168e-01,
#         4.63759825e-02, -1.50519356e-01,  4.12397444e-01,  6.07749581e-01,
#         2.13699579e-01,  1.15400456e-01, -4.84034181e-01, -6.80519417e-02,
#        -6.57899454e-02, -1.09116882e-01, -3.91274035e-01,  1.39867395e-01,
#        -1.97186276e-01,  5.57032228e-02,  1.52796537e-01,  4.87976596e-02,
#         2.53880233e-01, -1.26912996e-01,  2.59794712e-01,  3.80868852e-01,
#         1.26173124e-01,  1.85608193e-01, -3.39918630e-03,  2.98274189e-01,
#        -1.09917205e-03, -1.77747622e-01, -9.46148038e-02,  4.95251734e-03,
#        -4.19037133e-01,  4.00017917e-01, -2.27450460e-01,  4.61929291e-01,
#        -1.05721787e-01,  4.92052399e-02,  2.58687019e-01,  1.72109380e-01,
#        -3.82883698e-02, -1.76663190e-01,  4.70414795e-02,  1.28709853e-01,
# ...

# %%
np.inner(bert_embeddings_512[list(bert_embeddings_512.keys())[0]], bert_embeddings_512[list(bert_embeddings_512.keys())[0]]) / (norm(bert_embeddings_512[list(bert_embeddings_512.keys())[0]]) * norm(bert_embeddings_512[list(bert_embeddings_512.keys())[0]]))
# Out:
# 1.0

# %% [markdown]
# # Import Global Q-A Test Dictionary

# %%
test_from_file = open('/content/drive/MyDrive/Colab Notebooks/W266 Final Project/data/q_a_dict_test.pickle', 'rb')
test_qa_dict = pickle.load(test_from_file)
len(test_qa_dict)
# Out:
# 3063

# %% [markdown]
# # Create Cosine Similarity Dictionary

# %%
cosine_similarity_dict = similarity_score_dicts.create_similarity_score_dict(test_qa_dict, bert_embeddings_512, 'cosine')
len(cosine_similarity_dict)
# Out:
# 3063

# %% [markdown]
# # Create Rankings Dictionary

# %%
rankings_dict = similarity_score_dicts.compute_rankings(cosine_similarity_dict)
len(rankings_dict)
# Out:
# 3063

# %% [markdown]
# # Evaluate Results

# %%
evaluation.calculate_mrr(test_qa_dict, rankings_dict)
# Out:
# MRR: 0.565571413024889
# 0.565571413024889

# %%
evaluation.calculate_accuracy(test_qa_dict, rankings_dict)
# Out:
# Number correct: 1206
# Number incorrect 1857
# Total: 3063
# Accuracy: 39.373163565132224
# 39.373163565132224

# %%
evaluation.calculate_metrics(test_qa_dict, rankings_dict)
# Out:
# TP: 1206
# FP: 1856
# TN: 25708
# FN: 1860
# Precision: 0.39386022207707383
# Recall: 0.3933463796477495
# Accuracy: 0.878681031668299
# (0.39386022207707383, 0.3933463796477495, 0.878681031668299)

# %%
1206+1856+25708+1860
# Out:
# 30630

# %%
rankings_dict
# Out:
# {55661929: [(55662134, 4),
#   (55662053, 2),
#   (55661981, 1),
#   (64717925, 3),
#   (52250747, 9),
#   (47805233, 8),
#   (60398311, 5),
#   (47860893, 10),
#   (50565510, 7),
#   (54576739, 6)],
#  55664544: [(55664726, 5),
#   (55664585, 1),
#   (55664663, 2),
#   (51611111, 6),
#   (55118801, 7),
#   (61665527, 10),
#   (58582708, 8),
#   (59407189, 9),
#   (61027439, 4),
#   (42335581, 3)],
#  55644043: [(55665839, 10),
#   (55644071, 3),
#   (55644063, 6),
#   (43736281, 7),
#   (56789874, 5),
#   (61598381, 1),
#   (38446230, 8),
#   (57796365, 2),
#   (60590369, 9),
#   (37491434, 4)],
#  55668648: [(55669044, 7),
#   (55668752, 1),
#   (40313673, 8),
#   (61019118, 6),
#   (42076860, 9),
#   (46987965, 2),
#   (42858938, 3),
#   (55284252, 4),
#   (62841773, 5),
#   (42798604, 10)],
#  55707618: [(55708016, 3),
#   (62266543, 8),
#   (41499488, 2),
#   (51143548, 9),
#   (35772065, 6),
#   (50058945, 10),
#   (38295966, 4),
#   (46439272, 7),
#   (56278456, 1),
# ...
